# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Получение списка классов

# %% [markdown]
# Вытащим список классов товаров из справочника:

# %%
classesData = pd.read_excel("../../data/Справочники/Кабель справочник МТР.xlsx")

# %%
classesData.head()
# Out:
#    Материал              Краткий текст материала      Класс  \
# 0   1012856                  КАБЕЛЬ ИНТЕРФЕЙСНЫЙ      G2170
# 1   1013961                      Кабель КГ 3х2,5  G21050101
# 2   1028224                       Кабель КГ 4х10  G21050101
# 3   1030875                      Кабель КГ 2х2,5  G21050101
# 4   1036918  Саморегул.греющий кабель 20QTVR2-CT      G2110
#
#                                  Название
# 0  ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 1       Кабели силовые с изоляцией из ЭПР
# 2       Кабели силовые с изоляцией из ЭПР
# 3       Кабели силовые с изоляцией из ЭПР
# 4                          Кабели греющие

# %% [markdown]
# Важно! Читаемые названия классов из справочника могут не совпадать с читаемыми названиями классов из ведомости!

# %%
classes = classesData['Класс'].astype(str).unique()

# %%
classes
# Out:
# array(['G2170', 'G21050101', 'G2110', 'G21050102', 'G21050301', 'G210402',
#        'G21040101', 'G2106', 'G210506', 'G210502', 'G21050104', 'G210470',
#        'G21050370', 'G2107', 'G21050302', 'G210509', 'G210404', 'G210514',
#        'G2160', 'G210508', 'G2109', 'G210513', 'G210512', 'G210511',
#        'G21040102', 'G21050103', 'G210403', 'G210504', 'G210507',
#        'G210515', 'G2114', 'G2112', 'G210102', 'G210505', 'G210503',
#        'G210516', 'G2104', 'G2108', 'G2111', 'G210510'], dtype=object)

# %%
len(classes)
# Out:
# 40

# %% [markdown]
# # Предварительная работа с историей оферт

# %% [markdown]
# Цель этого этапа работы с историей оферт - получить список тех айдишников поставщиков, которые появлялись в истории оферт.

# %%
offersData = pd.read_csv("../../data/Исторические данные по офертам поставщиков на лот.csv")

# %%
offersIDs = offersData['Кредитор'].unique().astype(int)

# %%
len(offersIDs)
# Out:
# 881

# %% [markdown]
# # Предварительная работа с историей закупок

# %% [markdown]
# Цель этого этапа работы с историей заказов - получить список тех айдишников поставщиков, которые появлялись в истории заказов

# %%
purchasesData = pd.read_csv("../../data/Исторические совершенные закупки товаров.csv")

# %%
purchasesIDs = purchasesData['Поставщик'].unique().astype(int)

# %%
len(purchasesIDs)
# Out:
# 300

# %% [markdown]
# Замечание: если вглядываться к совершённые закупки, то там много строк с пропуском в айдишнике поставщика

# %% [markdown]
# # Работа со справочником поставщиков

# %% [markdown]
# Загрузим файл с поставщиками:

# %%
suppliersData = pd.read_excel("../../data/Справочники/Справочник поставщиков.XLSX")

# %%
suppliersData
# Out:
#           Кредитор П/индекс         Город
# 0       0000000003      NaN          ОМСК
# 1       0000000004      NaN          ОМСК
# 2       0000000005      NaN          ОМСК
# 3       0000000006      NaN           NaN
# 4       0000000008      NaN          ОМСК
# ...            ...      ...           ...
# 219830        CITI   125047  ГОРОД МОСКВА
# 219831        KOMB   119107     Г. МОСКВА
# 219832         MMB   119034      Г.МОСКВА
# 219833        SOBI   121248        МОСКВА
# 219834         WLS      NaN           NaN
#
# [219835 rows x 3 columns]

# %% [markdown]
# Уберём тех поставщиков, для которых неизвестен ни город, ни почтовый индекс:

# %%
suppliersData = suppliersData[suppliersData['П/индекс'].notna() | suppliersData['Город'].notna()]

# %%
suppliersData
# Out:
#           Кредитор П/индекс         Город
# 0       0000000003      NaN          ОМСК
# 1       0000000004      NaN          ОМСК
# 2       0000000005      NaN          ОМСК
# 4       0000000008      NaN          ОМСК
# 6       0000000010      NaN          ОМСК
# ...            ...      ...           ...
# 219829  9000000036   410008       САРАТОВ
# 219830        CITI   125047  ГОРОД МОСКВА
# 219831        KOMB   119107     Г. МОСКВА
# 219832         MMB   119034      Г.МОСКВА
# 219833        SOBI   121248        МОСКВА
#
# [214414 rows x 3 columns]

# %% [markdown]
# А теперь уберём тех поставщиков, у которых при непустом Почтовом индексе индекс точно не имеет формат:

# %%
suppliersData = suppliersData[suppliersData['П/индекс'].isnull() | suppliersData['П/индекс'].str.match('^[1-9]\d{5}$')]

# %%
suppliersData
# Out:
#           Кредитор П/индекс         Город
# 0       0000000003      NaN          ОМСК
# 1       0000000004      NaN          ОМСК
# 2       0000000005      NaN          ОМСК
# 4       0000000008      NaN          ОМСК
# 6       0000000010      NaN          ОМСК
# ...            ...      ...           ...
# 219829  9000000036   410008       САРАТОВ
# 219830        CITI   125047  ГОРОД МОСКВА
# 219831        KOMB   119107     Г. МОСКВА
# 219832         MMB   119034      Г.МОСКВА
# 219833        SOBI   121248        МОСКВА
#
# [212312 rows x 3 columns]

# %% [markdown]
# Последние четыре строчки крайне странные: айдишники в них имеют буквенный формат. Исключим их:

# %%
suppliersData = suppliersData.head(-4)

# %%
suppliersData
# Out:
#           Кредитор П/индекс         Город
# 0       0000000003      NaN          ОМСК
# 1       0000000004      NaN          ОМСК
# 2       0000000005      NaN          ОМСК
# 4       0000000008      NaN          ОМСК
# 6       0000000010      NaN          ОМСК
# ...            ...      ...           ...
# 219822  9000000026   347540  Г.ПРОЛЕТАРСК
# 219823  9000000027   352900     Г.АРМАВИР
# 219824  9000000028   403870    Г. КАМЫШИН
# 219825  9000000029      NaN  ГОРОД МОСКВА
# 219829  9000000036   410008       САРАТОВ
#
# [212308 rows x 3 columns]

# %% [markdown]
# Примерно каждый двадцатый айдишник имеет непустой город, но пустой индекс:

# %%
suppliersData[suppliersData['П/индекс'].isnull()]
# Out:
#           Кредитор П/индекс           Город
# 0       0000000003      NaN            ОМСК
# 1       0000000004      NaN            ОМСК
# 2       0000000005      NaN            ОМСК
# 4       0000000008      NaN            ОМСК
# 6       0000000010      NaN            ОМСК
# ...            ...      ...             ...
# 219625  7175110781      NaN        ТОБОЛЬСК
# 219630  7175110786      NaN  ВЯТСКИЕ ПОЛЯНЫ
# 219758  8000000076      NaN       Г. МОСКВА
# 219787  8000000132      NaN       Г. МОСКВА
# 219825  9000000029      NaN    ГОРОД МОСКВА
#
# [10296 rows x 3 columns]

# %% [markdown]
# Начнём всматриваться в почтовые индексы: белорусские и казахстанские индексы имеют схожий с российским формат. Чтобы избавиться от них, введём лист российских индексов, который заполним из датабазы:

# %%
russianIndices = [0]*61325

# %%
with open('../../supplementary/post_indices.sql') as f:
    line = f.readline()
    line = f.readline()
    line = f.readline()
    line = f.readline()
    i = 0
    while i < 61325: 
        #print(line[:6])
        russianIndices[i] = int(line[:6])
        i += 1
        line = f.readline()
    f.close()

# %% [markdown]
# Создадим маски - массивы нулей и единиц. Три вида массивов: 0) Единицы там, где индекс пуст или совпадает по формату с российским. 1) Единицы там, где айдишник есть в списке оферт. 2) Единицы там, где айдишник есть в списке заказов

# %%
mask0 = np.zeros(len(suppliersData), dtype=bool)
mask1 = np.zeros(len(suppliersData), dtype=bool)
mask2 = np.zeros(len(suppliersData), dtype=bool)
for i in range(len(mask0)):
    try:
        mask0[i] = (int(suppliersData.iloc[i]['П/индекс'])) in russianIndices
    except ValueError:
        mask0[i] = True
    mask1[i] = (int(suppliersData.iloc[i]['Кредитор'])) in offersIDs
    mask2[i] = (int(suppliersData.iloc[i]['Кредитор'])) in purchasesIDs
    if (i%1000 == 0):
        print(i, mask1[i])
    #mask[i] += mask0[i]
# Out:
# 0 False
# 1000 False
# 2000 False
# 3000 False
# 4000 False
# 5000 False
# 6000 False
# 7000 False
# 8000 False
# 9000 False
# 10000 False
# 11000 False
# 12000 False
# 13000 False
# 14000 False
# 15000 False
# 16000 False
# 17000 False
# 18000 False
# 19000 False
# 20000 False
# 21000 False
# 22000 False
# 23000 False
# 24000 False
# 25000 False
# 26000 False
# 27000 False
# 28000 False
# 29000 False
# 30000 False
# 31000 False
# 32000 False
# 33000 False
# 34000 False
# 35000 False
# 36000 False
# 37000 False
# 38000 False
# 39000 False
# 40000 False
# 41000 False
# 42000 False
# 43000 False
# 44000 False
# 45000 False
# 46000 False
# 47000 False
# 48000 False
# 49000 True
# 50000 False
# 51000 False
# 52000 False
# 53000 False
# 54000 False
# 55000 False
# 56000 False
# 57000 False
# 58000 False
# 59000 False
# 60000 False
# 61000 False
# 62000 False
# 63000 False
# 64000 False
# 65000 False
# 66000 False
# 67000 False
# 68000 False
# 69000 False
# 70000 False
# 71000 False
# 72000 False
# 73000 False
# 74000 False
# 75000 False
# 76000 False
# 77000 False
# 78000 False
# 79000 False
# 80000 False
# 81000 False
# 82000 False
# 83000 False
# 84000 False
# 85000 False
# 86000 False
# 87000 False
# 88000 False
# 89000 False
# 90000 False
# 91000 False
# 92000 False
# 93000 False
# 94000 False
# 95000 False
# 96000 False
# 97000 False
# 98000 False
# 99000 False
# 100000 False
# 101000 False
# 102000 False
# 103000 False
# 104000 False
# 105000 False
# 106000 False
# 107000 False
# 108000 False
# 109000 False
# 110000 False
# 111000 False
# 112000 False
# 113000 False
# 114000 False
# 115000 False
# 116000 False
# 117000 False
# 118000 False
# 119000 False
# 120000 False
# 121000 False
# 122000 False
# 123000 False
# 124000 False
# 125000 False
# 126000 False
# 127000 False
# 128000 False
# 129000 False
# 130000 False
# 131000 False
# 132000 False
# 133000 False
# 134000 False
# 135000 False
# 136000 False
# 137000 False
# 138000 False
# 139000 False
# 140000 False
# 141000 False
# 142000 False
# 143000 False
# 144000 False
# 145000 False
# 146000 False
# 147000 False
# 148000 False
# 149000 False
# 150000 False
# 151000 False
# 152000 False
# 153000 False
# 154000 False
# 155000 False
# 156000 False
# 157000 False
# 158000 False
# 159000 False
# 160000 False
# 161000 False
# 162000 False
# 163000 False
# 164000 False
# 165000 False
# 166000 False
# 167000 False
# 168000 False
# 169000 False
# 170000 False
# 171000 False
# 172000 False
# 173000 False
# 174000 False
# 175000 False
# 176000 False
# 177000 False
# 178000 False
# 179000 False
# 180000 False
# 181000 False
# 182000 False
# 183000 False
# 184000 False
# 185000 False
# 186000 False
# 187000 False
# 188000 False
# 189000 False
# 190000 False
# 191000 False
# 192000 False
# 193000 False
# 194000 False
# 195000 False
# 196000 False
# 197000 False
# 198000 False
# 199000 False
# 200000 False
# 201000 False
# 202000 False
# 203000 False
# 204000 False
# 205000 False
# 206000 False
# 207000 False
# 208000 False
# 209000 False
# 210000 False
# 211000 False
# 212000 False

# %% [markdown]
# Размеры множеств первой маски, второй, их объединения и пересечения:

# %%
print(np.sum(mask1), np.sum(mask2), np.sum(mask1+mask2), np.sum(mask1*mask2))
# Out:
# 879 293 933 239

# %% [markdown]
# А так же все их пересечения с нулевой маской:

# %%
print(np.sum(mask1*mask0), np.sum(mask2*mask0), np.sum((mask1+mask2)*mask0), np.sum(mask1*mask2*mask0))
# Out:
# 877 292 930 239

# %%
suppliersData = suppliersData[(mask1+mask2)*mask0]

# %%
suppliersData
# Out:
#           Кредитор П/индекс                Город
# 51      0000000059   629807  Г.О. ГОРОД НОЯБРЬСК
# 1052    0000001198   162608      ГОРОД ЧЕРЕПОВЕЦ
# 1525    0000001754   628464       ГОРОД РАДУЖНЫЙ
# 5204    0000005811   644040           ГОРОД ОМСК
# 7724    0000008536   644040           ГОРОД ОМСК
# ...            ...      ...                  ...
# 219030  7175110174   628684               МЕГИОН
# 219123  7175110267   628684               МЕГИОН
# 219128  7175110272   625033               ТЮМЕНЬ
# 219272  7175110419   628602        НИЖНЕВАРТОВСК
# 219280  7175110428   628624        НИЖНЕВАРТОВСК
#
# [930 rows x 3 columns]

# %%
suppliersData[suppliersData['П/индекс'].isnull()]
# Out:
#           Кредитор П/индекс              Город
# 96701   0000104691      NaN  САНКТ-ПЕТЕРБУРГ Г
# 161797  7139204246      NaN             МЕГИОН

# %%
suppliersIDs = suppliersData['Кредитор'].astype(int).to_numpy()

# %% [markdown]
# Обратим внимание на количество уникальных почтовых индексов и их отличие от размера списка поставщиков:

# %%
len(suppliersData['П/индекс'].unique())
# Out:
# 612

# %% [markdown]
# Уникальных индексов в списке всего 612 штук. Для крупных городов это кажется логичным - в примерно одном районе могут располагаться два производителя. Но требуется дополнительное исследование на совпадение айдишников для поставщиков в малых городах. Ручками предлагаю поглядеть в интернете на поставщиков кабелей в каком-то малом городе. Если он в городе один, а в таблице из такого города поставляют два разных айдишника - будем тогда думать. А пока считаем, что если айдишники разные, то разные и поставщики

# %% [markdown]
# Итого мы заимели список из 930 поставщиков, которые когда-либо (в рамках известных нам данных) что-либо продавали или предлагали продать.

# %% [markdown]
# Для реальной работы этот пайплайн нужно автоматизировать: завернуть всё в функции, реализовать возможность добавления поставщика к уже существующей таблице поставщиков

# %% [markdown]
# # Классификация поставщиков

# %% [markdown]
# ## Добавление новых колонок в список поставщиков

# %% [markdown]
# Имея список нужных нам поставщиков, дадим каждому в соответствие то, сколько раз он предлагал продать (или продавал) товар данного класа. Для этого нам надо поработать с историей закупок

# %% [markdown]
# Для начала добавим в таблицу со списком поставщиков столбцы, названия которых имеют названия классов. Каждый раз, когда поставщик предлагал продать или продавал товар такого класса, добавим в строку этого поставщика в столбец этого класса единицу

# %%
classes
# Out:
# array(['G2170', 'G21050101', 'G2110', 'G21050102', 'G21050301', 'G210402',
#        'G21040101', 'G2106', 'G210506', 'G210502', 'G21050104', 'G210470',
#        'G21050370', 'G2107', 'G21050302', 'G210509', 'G210404', 'G210514',
#        'G2160', 'G210508', 'G2109', 'G210513', 'G210512', 'G210511',
#        'G21040102', 'G21050103', 'G210403', 'G210504', 'G210507',
#        'G210515', 'G2114', 'G2112', 'G210102', 'G210505', 'G210503',
#        'G210516', 'G2104', 'G2108', 'G2111', 'G210510'], dtype=object)

# %%
len(suppliersData)
# Out:
# 930

# %%
suppliersClassificationData = suppliersData.copy()

# %%
emptyColumn = np.zeros(len(suppliersClassificationData), dtype=int)

# %%
for i, cableClass in enumerate(classes):
    currentColumnsAmount = suppliersClassificationData.shape[1]
    suppliersClassificationData.insert(currentColumnsAmount, cableClass, emptyColumn)

# %%
suppliersClassificationData
# Out:
#           Кредитор П/индекс                Город  G2170  G21050101  G2110  \
# 51      0000000059   629807  Г.О. ГОРОД НОЯБРЬСК      0          0      0
# 1052    0000001198   162608      ГОРОД ЧЕРЕПОВЕЦ      0          0      0
# 1525    0000001754   628464       ГОРОД РАДУЖНЫЙ      0          0      0
# 5204    0000005811   644040           ГОРОД ОМСК      0          0      0
# 7724    0000008536   644040           ГОРОД ОМСК      0          0      0
# ...            ...      ...                  ...    ...        ...    ...
# 219030  7175110174   628684               МЕГИОН      0          0      0
# 219123  7175110267   628684               МЕГИОН      0          0      0
# 219128  7175110272   625033               ТЮМЕНЬ      0          0      0
# 219272  7175110419   628602        НИЖНЕВАРТОВСК      0          0      0
# 219280  7175110428   628624        НИЖНЕВАРТОВСК      0          0      0
#
#         G21050102  G21050301  G210402  G21040101  ...  G2114  G2112  G210102  \
# 51              0          0        0          0  ...      0      0        0
# 1052            0          0        0          0  ...      0      0        0
# 1525            0          0        0          0  ...      0      0        0
# 5204            0          0        0          0  ...      0      0        0
# 7724            0          0        0          0  ...      0      0        0
# ...           ...        ...      ...        ...  ...    ...    ...      ...
# 219030          0          0        0          0  ...      0      0        0
# 219123          0          0        0          0  ...      0      0        0
# 219128          0          0        0          0  ...      0      0        0
# 219272          0          0        0          0  ...      0      0        0
# 219280          0          0        0          0  ...      0      0        0
#
#         G210505  G210503  G210516  G2104  G2108  G2111  G210510
# 51            0        0        0      0      0      0        0
# 1052          0        0        0      0      0      0        0
# 1525          0        0        0      0      0      0        0
# 5204          0        0        0      0      0      0        0
# 7724          0        0        0      0      0      0        0
# ...         ...      ...      ...    ...    ...    ...      ...
# 219030        0        0        0      0      0      0        0
# 219123        0        0        0      0      0      0        0
# 219128        0        0        0      0      0      0        0
# 219272        0        0        0      0      0      0        0
# 219280        0        0        0      0      0      0        0
#
# [930 rows x 43 columns]

# %% [markdown]
# ## Заполнение новых колонок из списка закупок

# %% [markdown]
# Теперь начнём заполнять список поставщиков и из истории закупок, и из истории оферт - это две независмые таблицы, которые нам нужно обработать

# %% [markdown]
# Начнём вглядываться в историю закупок:

# %%
purchasesData
# Out:
#        Заявка на закупку  Позиц. Статус плана МТО    Текст статуса плана МТО  \
# 0               10928585      30               P4  Проработано с поставщиком
# 1               10928863      50               P5              Создан запрос
# 2               10928863      60               P5              Создан запрос
# 3               10929730     210               P5              Создан запрос
# 4               10929730     220               P5              Создан запрос
# ...                  ...     ...              ...                        ...
# 39525           11625397      20               P4  Проработано с поставщиком
# 39526           11625868      10               P1       Предварительно готов
# 39527           11625929      60               P1       Предварительно готов
# 39528           11625929     170               P1       Предварительно готов
# 39529           11625929     210               P1       Предварительно готов
#
#            Материал                            Материал Имя Базисная ЕИ  \
# 0      770000818063  Кабель FYO2RMU 2х4х4хSML 90756м Nestor          ШТ
# 1      770000594878   Кабель ИнСил-ОЭвзнг(А)-ХЛ 4х2х1,0-660          КМ
# 2      770000831667    Кабель К9РВСБПМнг(А)-HF 4х1,5ок(N)-1          КМ
# 3      770000869461           Провод ПуВнг(А)-LS 1х1,0 (PE)          КМ
# 4      770000869463          Провод ПуГВнг(А)-LS 1х6,0 (PE)          КМ
# ...             ...                                     ...         ...
# 39525  770000568321            Провод ПуГВнг(А)-LS 1х25 з-ж          КМ
# 39526  770000872682           Кабель ВБШвнг(А)-ХЛ 3х185мс-6          КМ
# 39527  770001534234            Кабель ВВГнг(A)-LS 3х1,5ок-1          КМ
# 39528  770001757817              Кабель ВВГнг(A)-LS 3х2,5-1          КМ
# 39529  770000434863     Кабель SkyNet/FTP 4х2х0,51 5е in/Cu           М
#
#       АЕИ заказа  Кол-во к закупу, БЕИ  Кол-во к закупу, АЕИ  ...  \
# 0             ШТ                 2.000                 2.000  ...
# 1             КМ                 0.695                 0.695  ...
# 2             КМ                 0.320                 0.320  ...
# 3             КМ                 0.030                 0.030  ...
# 4             КМ                 0.030                 0.030  ...
# ...          ...                   ...                   ...  ...
# 39525         КМ                 0.150                 0.150  ...
# 39526         КМ                 0.855                 0.855  ...
# 39527         КМ                 0.100                 0.100  ...
# 39528         КМ                 0.080                 0.080  ...
# 39529          М                82.000                82.000  ...
#
#       План.сумма с НДС 20% Цена поставки с НДС  Валюта  Поставщик  \
# 0              13097296.44          6548648.22     RUB    55019.0
# 1                479687.14           622498.09     RUB    72148.0
# 2                142496.92           149508.00     RUB    54948.0
# 3                 34092.00             9800.67     RUB    58691.0
# 4                 36000.00            49400.00     RUB    58691.0
# ...                    ...                 ...     ...        ...
# 39525             35683.20                0.00     RUB        NaN
# 39526           5106402.00                0.00     RUB        NaN
# 39527              8149.60                0.00     RUB        NaN
# 39528              9966.56                0.00     RUB        NaN
# 39529             14558.28                0.00     RUB        NaN
#
#        Код класса МТР                       Наим.Код кл.       ID лота  \
# 0               G2109        Кабели волоконно-оптические  1.000003e+11
# 1               G2106      Кабели монтажные и управления  1.000004e+11
# 2           G21050101  Кабели силовые с изоляцией из ЭПР  1.000004e+11
# 3             G210511                    Провода силовые  1.000003e+11
# 4             G210511                    Провода силовые  1.000003e+11
# ...               ...                                ...           ...
# 39525         G210511                    Провода силовые  1.000008e+11
# 39526       G21050102  Кабели силовые с изоляцией из ПВХ           NaN
# 39527       G21050102  Кабели силовые с изоляцией из ПВХ  1.000008e+11
# 39528       G21050102  Кабели силовые с изоляцией из ПВХ  1.000008e+11
# 39529       G21050301                         Витая пара  1.000008e+11
#
#        Грузополучатель   Клиент  ГПЗ Способ закупки
# 0           20000447.0  39295.0                 NaN
# 1           20001383.0  64025.0  Конкурентный отбор
# 2           20001383.0  64025.0  Конкурентный отбор
# 3           20000537.0  57650.0  Конкурентный отбор
# 4           20000537.0  57650.0  Конкурентный отбор
# ...                ...      ...                 ...
# 39525       20000734.0  50630.0                 NaN
# 39526       20001013.0  27605.0                 NaN
# 39527       20001078.0  78154.0                 NaN
# 39528       20001078.0  78154.0                 NaN
# 39529       20001078.0  78154.0                 NaN
#
# [39530 rows x 24 columns]

# %%
purchasesAmount = len(purchasesData)

# %%
indices = suppliersClassificationData.index

# %%
for i in range(purchasesAmount):
    if (i % 1000 == 0):
        print(i)
    #suppliersClassificationData[purchasesData.loc[i]['Код класса МТР']].loc[purchasesData['Поставщик'].atype(int) == ]
    #if 
    for j in range(len(suppliersClassificationData)):
        #print(int(purchasesData.loc[i, 'Поставщик']))
        #print(int(suppliersClassificationData.loc[indices[i], 'Кредитор']))
        try:
            if int(purchasesData.loc[i, 'Поставщик']) == int(suppliersClassificationData.loc[indices[j], 'Кредитор']):
                #print(i, j)
                suppliersClassificationData.at[indices[j], purchasesData.loc[i, 'Код класса МТР']] += 1
                #print(i, j, suppliersClassificationData.at[indices[i], purchasesData.loc[i, 'Код класса МТР']])
                break
        except ValueError:
            break
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000

# %%
suppliersClassificationData
# Out:
#           Кредитор П/индекс                Город  G2170  G21050101  G2110  \
# 51      0000000059   629807  Г.О. ГОРОД НОЯБРЬСК      1          2      1
# 1052    0000001198   162608      ГОРОД ЧЕРЕПОВЕЦ      0          0      0
# 1525    0000001754   628464       ГОРОД РАДУЖНЫЙ      0          0      0
# 5204    0000005811   644040           ГОРОД ОМСК      0          0      0
# 7724    0000008536   644040           ГОРОД ОМСК      0          2      2
# ...            ...      ...                  ...    ...        ...    ...
# 219030  7175110174   628684               МЕГИОН      0          0      0
# 219123  7175110267   628684               МЕГИОН      0          2      0
# 219128  7175110272   625033               ТЮМЕНЬ      0          1      0
# 219272  7175110419   628602        НИЖНЕВАРТОВСК      0          0      0
# 219280  7175110428   628624        НИЖНЕВАРТОВСК      0          0      0
#
#         G21050102  G21050301  G210402  G21040101  ...  G2114  G2112  G210102  \
# 51            101          0        0          0  ...      0      0        0
# 1052            0          0        0          0  ...      0      0        0
# 1525            0          0        0          0  ...      0      0        0
# 5204            0          0        0          0  ...      0      0        0
# 7724           15          1        0          0  ...      0      0        0
# ...           ...        ...      ...        ...  ...    ...    ...      ...
# 219030          1          0        0          0  ...      0      0        0
# 219123          1          0        0          1  ...      0      0        0
# 219128          0          0        2          0  ...      0      0        0
# 219272          0          0       12          2  ...      0      0        0
# 219280          0          0        1          2  ...      0      0        0
#
#         G210505  G210503  G210516  G2104  G2108  G2111  G210510
# 51            0        0        5      0      0      0        0
# 1052          0        0        0      0      0      0        0
# 1525          0        0        0      0      0      0        0
# 5204          0        0        0      0      0      0        0
# 7724          0        0        0      0      0      0        0
# ...         ...      ...      ...    ...    ...    ...      ...
# 219030        0        0        0      0      0      0        0
# 219123        0        0        0      0      0      0        0
# 219128        0        0        0      0      0      0        0
# 219272        0        0        0      0      0      0        0
# 219280        0        0        0      0      0      0        0
#
# [930 rows x 43 columns]

# %% [markdown]
# ## Заполнение новых колонок из списка оферт

# %% [markdown]
# Ааналогично начнём вглядываться в историю оферт:

# %%
offersData
# Out:
#               Лот ID      Кредитор  Сумма во ВВ      Материал  \
# 0       1.000005e+11  7.542200e+04       137.00       1118280
# 1       1.000005e+11  9.429300e+04       567.00       1118280
# 2       1.000005e+11  9.429300e+04       567.00       1118280
# 3       1.000005e+11  9.429300e+04       567.00       1118280
# 4       1.000005e+11  9.450100e+04       619.76       1118280
# ...              ...           ...          ...           ...
# 339964  1.000008e+11  7.175110e+09       249.17  770001801168
# 339965  1.000008e+11  7.175110e+09       249.17  770001801168
# 339966  1.000006e+11  5.900000e+01    186374.00  980004700197
# 339967  1.000006e+11  5.900000e+01    186374.00  980004700197
# 339968  1.000006e+11  5.900000e+01    186374.00  980004700197
#
#                                  Краткий текст  Влт  Курс  \
# 0       Площадка самоклеящаяся Hyperline HW-3A  RUB   1.0
# 1       Площадка самоклеящаяся Hyperline HW-3A  RUB   1.0
# 2       Площадка самоклеящаяся Hyperline HW-3A  RUB   1.0
# 3       Площадка самоклеящаяся Hyperline HW-3A  RUB   1.0
# 4       Площадка самоклеящаяся Hyperline HW-3A  RUB   1.0
# ...                                        ...  ...   ...
# 339964                     Кабель DEXP/1041894  RUB   1.0
# 339965                     Кабель DEXP/1041894  RUB   1.0
# 339966                        ПРОВОД АС-120/19  RUB   1.0
# 339967                        ПРОВОД АС-120/19  RUB   1.0
# 339968                        ПРОВОД АС-120/19  RUB   1.0
#
#                        Краткий текст материала      Класс  \
# 0       Площадка самоклеящаяся Hyperline HW-3A      G2170
# 1       Площадка самоклеящаяся Hyperline HW-3A      G2170
# 2       Площадка самоклеящаяся Hyperline HW-3A      G2170
# 3       Площадка самоклеящаяся Hyperline HW-3A      G2170
# 4       Площадка самоклеящаяся Hyperline HW-3A      G2170
# ...                                        ...        ...
# 339964                     Кабель DEXP/1041894  G21050301
# 339965                     Кабель DEXP/1041894  G21050301
# 339966                        ПРОВОД АС-120/19      G2170
# 339967                        ПРОВОД АС-120/19      G2170
# 339968                        ПРОВОД АС-120/19      G2170
#
#                                       Название
# 0       ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 1       ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 2       ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 3       ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 4       ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# ...                                        ...
# 339964                              Витая пара
# 339965                              Витая пара
# 339966  ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 339967  ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
# 339968  ПРОДУКЦИЯ КАБЕЛЬНАЯ НЕ НОРМАЛИЗОВАННАЯ
#
# [339969 rows x 10 columns]

# %%
offersAmount = len(offersData)

# %%
indices = suppliersClassificationData.index

# %%
for i in range(offersAmount):
    if (i % 1000 == 0):
        print(i)
    #suppliersClassificationData[purchasesData.loc[i]['Код класса МТР']].loc[purchasesData['Поставщик'].atype(int) == ]
    #if 
    for j in range(len(suppliersClassificationData)):
        #print(int(purchasesData.loc[i, 'Поставщик']))
        #print(int(suppliersClassificationData.loc[indices[i], 'Кредитор']))
        try:
            if int(offersData.loc[i, 'Кредитор']) == int(suppliersClassificationData.loc[indices[j], 'Кредитор']):
                #print(i, j)
                suppliersClassificationData.at[indices[j], offersData.loc[i, 'Класс']] += 1
                #print(i, j, suppliersClassificationData.at[indices[i], purchasesData.loc[i, 'Код класса МТР']])
                break
        except ValueError:
            break
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000

# %% [markdown]
# Итого мы получили:

# %%
suppliersClassificationData
# Out:
#           Кредитор П/индекс                Город  G2170  G21050101  G2110  \
# 51      0000000059   629807  Г.О. ГОРОД НОЯБРЬСК      4          3      2
# 1052    0000001198   162608      ГОРОД ЧЕРЕПОВЕЦ      0          0      1
# 1525    0000001754   628464       ГОРОД РАДУЖНЫЙ      0          0      0
# 5204    0000005811   644040           ГОРОД ОМСК     12          0      0
# 7724    0000008536   644040           ГОРОД ОМСК      0          3      8
# ...            ...      ...                  ...    ...        ...    ...
# 219030  7175110174   628684               МЕГИОН      0          0      0
# 219123  7175110267   628684               МЕГИОН      0         14      0
# 219128  7175110272   625033               ТЮМЕНЬ      0          4      0
# 219272  7175110419   628602        НИЖНЕВАРТОВСК      0          0      0
# 219280  7175110428   628624        НИЖНЕВАРТОВСК      0          0      0
#
#         G21050102  G21050301  G210402  G21040101  ...  G2114  G2112  G210102  \
# 51            207          0        2          0  ...      0      0        0
# 1052            0          0        0          0  ...      0      0        0
# 1525            0          0        0          0  ...      0      0        0
# 5204            0          0        0          0  ...      0      0        0
# 7724           68          1        0          0  ...      0      0        0
# ...           ...        ...      ...        ...  ...    ...    ...      ...
# 219030          1          0        0          0  ...      0      0        0
# 219123          4          0        0          4  ...      0      0        0
# 219128          0          0        8          0  ...      0      0        0
# 219272          0          0       48          8  ...      0      0        0
# 219280          0          3        4          8  ...      0      0        0
#
#         G210505  G210503  G210516  G2104  G2108  G2111  G210510
# 51            0        0        9      1      0      0        0
# 1052          0        0        0      0      0      0        0
# 1525          0        0        0      0      0      0        0
# 5204          0        0        0      0      0      0        0
# 7724          0        0        0      0      0      0        0
# ...         ...      ...      ...    ...    ...    ...      ...
# 219030        0        0        0      0      0      0        0
# 219123        0        0        0      0      0      0        0
# 219128        0        0        0      0      0      0        0
# 219272        0        0        0      0      0      0        0
# 219280        0        0        0      0      0      0        0
#
# [930 rows x 43 columns]

# %%
suppliersClassificationData.to_csv("./suppliersClassified")

# %% [markdown]
# # Песочница

# %% [markdown]
# # Устаревший код

# %% [markdown]
# Код дальше считается устаревшим, потому что он работал в предположении, что одному почтовому индексу соответствуют разные поставщики. Если это предположение окажется всё-таки верным, то следует использовать наработки отсюда.

# %% [markdown]
# Ничего, кроме почтового индекса и города (причём сам город нам не нужен - он закодирован в почтовом индексе) поставщика мы не знаем. Возможно, что есть два разных поставщика с одним почтовым индексом (тем более, как мне кажется, в больших городах), но на этом этапе мы пока не узнаем.
# Таким образом, считаем, что почтовый индекс однозначно задаёт нам поставщика.

# %%
assert False #чтобы следующие ячейки не запускались
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
len(suppliersData['П/индекс'].unique())

# %%
len(suppliersData['Город'].unique())

# %% [markdown]
# Дадим каждому почтовому индексу в соответствие набор айдишников, по которым поставщик числился в закупках и офертах:

# %%
suppliersPostalIndices = suppliersData['П/индекс'].unique()

# %% [markdown]
# Нас не интересует почтовый индекс 111111 (явно фигня какая-то), Nan-ы и индексы не российского формата (сразу обрубим иностранные компании)

# %%
suppliersIDDictionary = suppliersData.groupby('П/индекс')['Кредитор'].apply(list).to_dict()

# %%
t = 0
for postal_code, ids in suppliersIDDictionary.items():
    t += 1
    print(f'Почтовый индекс: {postal_code}, ID: {ids}')
    if t > 10:
        break

# %%
suppliersData[suppliersData['П/индекс'] == '105082']

# %%
P = r'^[1-9]\d{5}$' # выражение, ограничивающее нас российскими адресами
suppliersIDDictionary = dict(filter(lambda x: re.match(P, x[0]), suppliersIDDictionary.items()))

# %%
t = 0
for postal_code, ids in suppliersIDDictionary.items():
    t += 1
    print(f'Почтовый индекс: {postal_code}, ID: {ids}')
    if t > 10:
        break

# %%
len(suppliersData)

# %%
suppliersData[suppliersData['П/индекс'].isnull() & suppliersData['Город'].isnull()]

# %% [markdown]
# Оказалось, что не только РФ использует шестизначные почтовые индексы, но и, например, Казахстан - 010000
